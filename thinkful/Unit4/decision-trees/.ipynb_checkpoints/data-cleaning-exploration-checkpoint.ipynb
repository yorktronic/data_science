# %%
import graphlab
# import pandas as pd

# %%
sf = graphlab.SFrame('./db/samsungdata.csv')
# Out:
# [INFO] 1448753699 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to F:\Users\Ty\Anaconda\lib\site-packages\certifi\cacert.pem
# 1448753699 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to ty.walker@gmail.com and will expire on November 24, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-54028 - Server binary: F:\Users\Ty\Anaconda\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\Ty\AppData\Local\Temp\graphlab_server_1448753699.log.0
# [INFO] GraphLab Server Version: 1.7.1
# PROGRESS: Finished parsing file C:\Users\Ty\code\data_science\thinkful\Unit4\decision-trees\db\samsungdata.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.566032 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[long,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float,long,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file C:\Users\Ty\code\data_science\thinkful\Unit4\decision-trees\db\samsungdata.csv
# PROGRESS: Parsing completed. Parsed 7352 lines in 0.426024 secs.

# %%
# Function to remove unwanted characters and substrings. Returns a cleaned column name.
cols_new_names = {}
new_column_names = []

def removeUnwanted(col_name):
    chars_to_remove = ['()', '-', ',']
    for ch in chars_to_remove:
        if ch in col_name:
            col_name = col_name.replace(ch, '')
    return col_name

# %%
# Populate dictionary
sf_cols = sf.column_names()
for col in sf_cols:
    cols_new_names[col] = removeUnwanted(col)

cols_new_names
# Out:
# {'X1': 'X1',
#  'activity': 'activity',
#  'angle(X,gravityMean)': 'angle(XgravityMean)',
#  'angle(Y,gravityMean)': 'angle(YgravityMean)',
#  'angle(Z,gravityMean)': 'angle(ZgravityMean)',
#  'angle(tBodyAccJerkMean),gravityMean)': 'angle(tBodyAccJerkMean)gravityMean)',
#  'angle(tBodyAccMean,gravity)': 'angle(tBodyAccMeangravity)',
#  'angle(tBodyGyroJerkMean,gravityMean)': 'angle(tBodyGyroJerkMeangravityMean)',
#  'angle(tBodyGyroMean,gravityMean)': 'angle(tBodyGyroMeangravityMean)',
#  'fBodyAcc-bandsEnergy()-1,16': 'fBodyAccbandsEnergy116',
#  'fBodyAcc-bandsEnergy()-1,16.1': 'fBodyAccbandsEnergy116.1',
#  'fBodyAcc-bandsEnergy()-1,16.2': 'fBodyAccbandsEnergy116.2',
#  'fBodyAcc-bandsEnergy()-1,24': 'fBodyAccbandsEnergy124',
#  'fBodyAcc-bandsEnergy()-1,24.1': 'fBodyAccbandsEnergy124.1',
#  'fBodyAcc-bandsEnergy()-1,24.2': 'fBodyAccbandsEnergy124.2',
#  'fBodyAcc-bandsEnergy()-1,8': 'fBodyAccbandsEnergy18',
#  'fBodyAcc-bandsEnergy()-1,8.1': 'fBodyAccbandsEnergy18.1',
#  'fBodyAcc-bandsEnergy()-1,8.2': 'fBodyAccbandsEnergy18.2',
#  'fBodyAcc-bandsEnergy()-17,24': 'fBodyAccbandsEnergy1724',
#  'fBodyAcc-bandsEnergy()-17,24.1': 'fBodyAccbandsEnergy1724.1',
#  'fBodyAcc-bandsEnergy()-17,24.2': 'fBodyAccbandsEnergy1724.2',
#  'fBodyAcc-bandsEnergy()-17,32': 'fBodyAccbandsEnergy1732',
#  'fBodyAcc-bandsEnergy()-17,32.1': 'fBodyAccbandsEnergy1732.1',
#  'fBodyAcc-bandsEnergy()-17,32.2': 'fBodyAccbandsEnergy1732.2',
#  'fBodyAcc-bandsEnergy()-25,32': 'fBodyAccbandsEnergy2532',
#  'fBodyAcc-bandsEnergy()-25,32.1': 'fBodyAccbandsEnergy2532.1',
#  'fBodyAcc-bandsEnergy()-25,32.2': 'fBodyAccbandsEnergy2532.2',
#  'fBodyAcc-bandsEnergy()-25,48': 'fBodyAccbandsEnergy2548',
#  'fBodyAcc-bandsEnergy()-25,48.1': 'fBodyAccbandsEnergy2548.1',
#  'fBodyAcc-bandsEnergy()-25,48.2': 'fBodyAccbandsEnergy2548.2',
#  'fBodyAcc-bandsEnergy()-33,40': 'fBodyAccbandsEnergy3340',
#  'fBodyAcc-bandsEnergy()-33,40.1': 'fBodyAccbandsEnergy3340.1',
#  'fBodyAcc-bandsEnergy()-33,40.2': 'fBodyAccbandsEnergy3340.2',
#  'fBodyAcc-bandsEnergy()-33,48': 'fBodyAccbandsEnergy3348',
#  'fBodyAcc-bandsEnergy()-33,48.1': 'fBodyAccbandsEnergy3348.1',
#  'fBodyAcc-bandsEnergy()-33,48.2': 'fBodyAccbandsEnergy3348.2',
#  'fBodyAcc-bandsEnergy()-41,48': 'fBodyAccbandsEnergy4148',
#  'fBodyAcc-bandsEnergy()-41,48.1': 'fBodyAccbandsEnergy4148.1',
#  'fBodyAcc-bandsEnergy()-41,48.2': 'fBodyAccbandsEnergy4148.2',
#  'fBodyAcc-bandsEnergy()-49,56': 'fBodyAccbandsEnergy4956',
#  'fBodyAcc-bandsEnergy()-49,56.1': 'fBodyAccbandsEnergy4956.1',
#  'fBodyAcc-bandsEnergy()-49,56.2': 'fBodyAccbandsEnergy4956.2',
#  'fBodyAcc-bandsEnergy()-49,64': 'fBodyAccbandsEnergy4964',
#  'fBodyAcc-bandsEnergy()-49,64.1': 'fBodyAccbandsEnergy4964.1',
#  'fBodyAcc-bandsEnergy()-49,64.2': 'fBodyAccbandsEnergy4964.2',
#  'fBodyAcc-bandsEnergy()-57,64': 'fBodyAccbandsEnergy5764',
#  'fBodyAcc-bandsEnergy()-57,64.1': 'fBodyAccbandsEnergy5764.1',
#  'fBodyAcc-bandsEnergy()-57,64.2': 'fBodyAccbandsEnergy5764.2',
#  'fBodyAcc-bandsEnergy()-9,16': 'fBodyAccbandsEnergy916',
#  'fBodyAcc-bandsEnergy()-9,16.1': 'fBodyAccbandsEnergy916.1',
#  'fBodyAcc-bandsEnergy()-9,16.2': 'fBodyAccbandsEnergy916.2',
#  'fBodyAcc-energy()-X': 'fBodyAccenergyX',
#  'fBodyAcc-energy()-Y': 'fBodyAccenergyY',
#  'fBodyAcc-energy()-Z': 'fBodyAccenergyZ',
#  'fBodyAcc-entropy()-X': 'fBodyAccentropyX',
#  'fBodyAcc-entropy()-Y': 'fBodyAccentropyY',
#  'fBodyAcc-entropy()-Z': 'fBodyAccentropyZ',
#  'fBodyAcc-iqr()-X': 'fBodyAcciqrX',
#  'fBodyAcc-iqr()-Y': 'fBodyAcciqrY',
#  'fBodyAcc-iqr()-Z': 'fBodyAcciqrZ',
#  'fBodyAcc-kurtosis()-X': 'fBodyAcckurtosisX',
#  'fBodyAcc-kurtosis()-Y': 'fBodyAcckurtosisY',
#  'fBodyAcc-kurtosis()-Z': 'fBodyAcckurtosisZ',
#  'fBodyAcc-mad()-X': 'fBodyAccmadX',
#  'fBodyAcc-mad()-Y': 'fBodyAccmadY',
#  'fBodyAcc-mad()-Z': 'fBodyAccmadZ',
#  'fBodyAcc-max()-X': 'fBodyAccmaxX',
#  'fBodyAcc-max()-Y': 'fBodyAccmaxY',
#  'fBodyAcc-max()-Z': 'fBodyAccmaxZ',
#  'fBodyAcc-maxInds-X': 'fBodyAccmaxIndsX',
#  'fBodyAcc-maxInds-Y': 'fBodyAccmaxIndsY',
#  'fBodyAcc-maxInds-Z': 'fBodyAccmaxIndsZ',
#  'fBodyAcc-mean()-X': 'fBodyAccmeanX',
#  'fBodyAcc-mean()-Y': 'fBodyAccmeanY',
#  'fBodyAcc-mean()-Z': 'fBodyAccmeanZ',
#  'fBodyAcc-meanFreq()-X': 'fBodyAccmeanFreqX',
#  'fBodyAcc-meanFreq()-Y': 'fBodyAccmeanFreqY',
#  'fBodyAcc-meanFreq()-Z': 'fBodyAccmeanFreqZ',
#  'fBodyAcc-min()-X': 'fBodyAccminX',
#  'fBodyAcc-min()-Y': 'fBodyAccminY',
#  'fBodyAcc-min()-Z': 'fBodyAccminZ',
#  'fBodyAcc-skewness()-X': 'fBodyAccskewnessX',
#  'fBodyAcc-skewness()-Y': 'fBodyAccskewnessY',
#  'fBodyAcc-skewness()-Z': 'fBodyAccskewnessZ',
#  'fBodyAcc-sma()': 'fBodyAccsma',
#  'fBodyAcc-std()-X': 'fBodyAccstdX',
#  'fBodyAcc-std()-Y': 'fBodyAccstdY',
#  'fBodyAcc-std()-Z': 'fBodyAccstdZ',
#  'fBodyAccJerk-bandsEnergy()-1,16': 'fBodyAccJerkbandsEnergy116',
#  'fBodyAccJerk-bandsEnergy()-1,16.1': 'fBodyAccJerkbandsEnergy116.1',
#  'fBodyAccJerk-bandsEnergy()-1,16.2': 'fBodyAccJerkbandsEnergy116.2',
#  'fBodyAccJerk-bandsEnergy()-1,24': 'fBodyAccJerkbandsEnergy124',
#  'fBodyAccJerk-bandsEnergy()-1,24.1': 'fBodyAccJerkbandsEnergy124.1',
#  'fBodyAccJerk-bandsEnergy()-1,24.2': 'fBodyAccJerkbandsEnergy124.2',
#  'fBodyAccJerk-bandsEnergy()-1,8': 'fBodyAccJerkbandsEnergy18',
#  'fBodyAccJerk-bandsEnergy()-1,8.1': 'fBodyAccJerkbandsEnergy18.1',
#  'fBodyAccJerk-bandsEnergy()-1,8.2': 'fBodyAccJerkbandsEnergy18.2',
#  'fBodyAccJerk-bandsEnergy()-17,24': 'fBodyAccJerkbandsEnergy1724',
#  'fBodyAccJerk-bandsEnergy()-17,24.1': 'fBodyAccJerkbandsEnergy1724.1',
#  'fBodyAccJerk-bandsEnergy()-17,24.2': 'fBodyAccJerkbandsEnergy1724.2',
#  'fBodyAccJerk-bandsEnergy()-17,32': 'fBodyAccJerkbandsEnergy1732',
#  'fBodyAccJerk-bandsEnergy()-17,32.1': 'fBodyAccJerkbandsEnergy1732.1',
#  'fBodyAccJerk-bandsEnergy()-17,32.2': 'fBodyAccJerkbandsEnergy1732.2',
#  'fBodyAccJerk-bandsEnergy()-25,32': 'fBodyAccJerkbandsEnergy2532',
#  'fBodyAccJerk-bandsEnergy()-25,32.1': 'fBodyAccJerkbandsEnergy2532.1',
#  'fBodyAccJerk-bandsEnergy()-25,32.2': 'fBodyAccJerkbandsEnergy2532.2',
#  'fBodyAccJerk-bandsEnergy()-25,48': 'fBodyAccJerkbandsEnergy2548',
#  'fBodyAccJerk-bandsEnergy()-25,48.1': 'fBodyAccJerkbandsEnergy2548.1',
#  'fBodyAccJerk-bandsEnergy()-25,48.2': 'fBodyAccJerkbandsEnergy2548.2',
#  'fBodyAccJerk-bandsEnergy()-33,40': 'fBodyAccJerkbandsEnergy3340',
#  'fBodyAccJerk-bandsEnergy()-33,40.1': 'fBodyAccJerkbandsEnergy3340.1',
#  'fBodyAccJerk-bandsEnergy()-33,40.2': 'fBodyAccJerkbandsEnergy3340.2',
#  'fBodyAccJerk-bandsEnergy()-33,48': 'fBodyAccJerkbandsEnergy3348',
#  'fBodyAccJerk-bandsEnergy()-33,48.1': 'fBodyAccJerkbandsEnergy3348.1',
#  'fBodyAccJerk-bandsEnergy()-33,48.2': 'fBodyAccJerkbandsEnergy3348.2',
#  'fBodyAccJerk-bandsEnergy()-41,48': 'fBodyAccJerkbandsEnergy4148',
#  'fBodyAccJerk-bandsEnergy()-41,48.1': 'fBodyAccJerkbandsEnergy4148.1',
#  'fBodyAccJerk-bandsEnergy()-41,48.2': 'fBodyAccJerkbandsEnergy4148.2',
#  'fBodyAccJerk-bandsEnergy()-49,56': 'fBodyAccJerkbandsEnergy4956',
#  'fBodyAccJerk-bandsEnergy()-49,56.1': 'fBodyAccJerkbandsEnergy4956.1',
#  'fBodyAccJerk-bandsEnergy()-49,56.2': 'fBodyAccJerkbandsEnergy4956.2',
#  'fBodyAccJerk-bandsEnergy()-49,64': 'fBodyAccJerkbandsEnergy4964',
#  'fBodyAccJerk-bandsEnergy()-49,64.1': 'fBodyAccJerkbandsEnergy4964.1',
#  'fBodyAccJerk-bandsEnergy()-49,64.2': 'fBodyAccJerkbandsEnergy4964.2',
#  'fBodyAccJerk-bandsEnergy()-57,64': 'fBodyAccJerkbandsEnergy5764',
#  'fBodyAccJerk-bandsEnergy()-57,64.1': 'fBodyAccJerkbandsEnergy5764.1',
#  'fBodyAccJerk-bandsEnergy()-57,64.2': 'fBodyAccJerkbandsEnergy5764.2',
#  'fBodyAccJerk-bandsEnergy()-9,16': 'fBodyAccJerkbandsEnergy916',
#  'fBodyAccJerk-bandsEnergy()-9,16.1': 'fBodyAccJerkbandsEnergy916.1',
#  'fBodyAccJerk-bandsEnergy()-9,16.2': 'fBodyAccJerkbandsEnergy916.2',
#  'fBodyAccJerk-energy()-X': 'fBodyAccJerkenergyX',
#  'fBodyAccJerk-energy()-Y': 'fBodyAccJerkenergyY',
#  'fBodyAccJerk-energy()-Z': 'fBodyAccJerkenergyZ',
#  'fBodyAccJerk-entropy()-X': 'fBodyAccJerkentropyX',
#  'fBodyAccJerk-entropy()-Y': 'fBodyAccJerkentropyY',
#  'fBodyAccJerk-entropy()-Z': 'fBodyAccJerkentropyZ',
#  'fBodyAccJerk-iqr()-X': 'fBodyAccJerkiqrX',
#  'fBodyAccJerk-iqr()-Y': 'fBodyAccJerkiqrY',
#  'fBodyAccJerk-iqr()-Z': 'fBodyAccJerkiqrZ',
#  'fBodyAccJerk-kurtosis()-X': 'fBodyAccJerkkurtosisX',
#  'fBodyAccJerk-kurtosis()-Y': 'fBodyAccJerkkurtosisY',
#  'fBodyAccJerk-kurtosis()-Z': 'fBodyAccJerkkurtosisZ',
#  'fBodyAccJerk-mad()-X': 'fBodyAccJerkmadX',
#  'fBodyAccJerk-mad()-Y': 'fBodyAccJerkmadY',
#  'fBodyAccJerk-mad()-Z': 'fBodyAccJerkmadZ',
#  'fBodyAccJerk-max()-X': 'fBodyAccJerkmaxX',
#  'fBodyAccJerk-max()-Y': 'fBodyAccJerkmaxY',
#  'fBodyAccJerk-max()-Z': 'fBodyAccJerkmaxZ',
#  'fBodyAccJerk-maxInds-X': 'fBodyAccJerkmaxIndsX',
#  'fBodyAccJerk-maxInds-Y': 'fBodyAccJerkmaxIndsY',
#  'fBodyAccJerk-maxInds-Z': 'fBodyAccJerkmaxIndsZ',
#  'fBodyAccJerk-mean()-X': 'fBodyAccJerkmeanX',
#  'fBodyAccJerk-mean()-Y': 'fBodyAccJerkmeanY',
#  'fBodyAccJerk-mean()-Z': 'fBodyAccJerkmeanZ',
#  'fBodyAccJerk-meanFreq()-X': 'fBodyAccJerkmeanFreqX',
#  'fBodyAccJerk-meanFreq()-Y': 'fBodyAccJerkmeanFreqY',
#  'fBodyAccJerk-meanFreq()-Z': 'fBodyAccJerkmeanFreqZ',
#  'fBodyAccJerk-min()-X': 'fBodyAccJerkminX',
#  'fBodyAccJerk-min()-Y': 'fBodyAccJerkminY',
#  'fBodyAccJerk-min()-Z': 'fBodyAccJerkminZ',
#  'fBodyAccJerk-skewness()-X': 'fBodyAccJerkskewnessX',
#  'fBodyAccJerk-skewness()-Y': 'fBodyAccJerkskewnessY',
#  'fBodyAccJerk-skewness()-Z': 'fBodyAccJerkskewnessZ',
#  'fBodyAccJerk-sma()': 'fBodyAccJerksma',
#  'fBodyAccJerk-std()-X': 'fBodyAccJerkstdX',
#  'fBodyAccJerk-std()-Y': 'fBodyAccJerkstdY',
#  'fBodyAccJerk-std()-Z': 'fBodyAccJerkstdZ',
#  'fBodyAccMag-energy()': 'fBodyAccMagenergy',
#  'fBodyAccMag-entropy()': 'fBodyAccMagentropy',
#  'fBodyAccMag-iqr()': 'fBodyAccMagiqr',
#  'fBodyAccMag-kurtosis()': 'fBodyAccMagkurtosis',
#  'fBodyAccMag-mad()': 'fBodyAccMagmad',
#  'fBodyAccMag-max()': 'fBodyAccMagmax',
#  'fBodyAccMag-maxInds': 'fBodyAccMagmaxInds',
#  'fBodyAccMag-mean()': 'fBodyAccMagmean',
#  'fBodyAccMag-meanFreq()': 'fBodyAccMagmeanFreq',
#  'fBodyAccMag-min()': 'fBodyAccMagmin',
#  'fBodyAccMag-skewness()': 'fBodyAccMagskewness',
#  'fBodyAccMag-sma()': 'fBodyAccMagsma',
#  'fBodyAccMag-std()': 'fBodyAccMagstd',
#  'fBodyBodyAccJerkMag-energy()': 'fBodyBodyAccJerkMagenergy',
#  'fBodyBodyAccJerkMag-entropy()': 'fBodyBodyAccJerkMagentropy',
#  'fBodyBodyAccJerkMag-iqr()': 'fBodyBodyAccJerkMagiqr',
#  'fBodyBodyAccJerkMag-kurtosis()': 'fBodyBodyAccJerkMagkurtosis',
#  'fBodyBodyAccJerkMag-mad()': 'fBodyBodyAccJerkMagmad',
#  'fBodyBodyAccJerkMag-max()': 'fBodyBodyAccJerkMagmax',
#  'fBodyBodyAccJerkMag-maxInds': 'fBodyBodyAccJerkMagmaxInds',
#  'fBodyBodyAccJerkMag-mean()': 'fBodyBodyAccJerkMagmean',
#  'fBodyBodyAccJerkMag-meanFreq()': 'fBodyBodyAccJerkMagmeanFreq',
#  'fBodyBodyAccJerkMag-min()': 'fBodyBodyAccJerkMagmin',
#  'fBodyBodyAccJerkMag-skewness()': 'fBodyBodyAccJerkMagskewness',
#  'fBodyBodyAccJerkMag-sma()': 'fBodyBodyAccJerkMagsma',
#  'fBodyBodyAccJerkMag-std()': 'fBodyBodyAccJerkMagstd',
#  'fBodyBodyGyroJerkMag-energy()': 'fBodyBodyGyroJerkMagenergy',
#  'fBodyBodyGyroJerkMag-entropy()': 'fBodyBodyGyroJerkMagentropy',
#  'fBodyBodyGyroJerkMag-iqr()': 'fBodyBodyGyroJerkMagiqr',
#  'fBodyBodyGyroJerkMag-kurtosis()': 'fBodyBodyGyroJerkMagkurtosis',
#  'fBodyBodyGyroJerkMag-mad()': 'fBodyBodyGyroJerkMagmad',
#  'fBodyBodyGyroJerkMag-max()': 'fBodyBodyGyroJerkMagmax',
#  'fBodyBodyGyroJerkMag-maxInds': 'fBodyBodyGyroJerkMagmaxInds',
#  'fBodyBodyGyroJerkMag-mean()': 'fBodyBodyGyroJerkMagmean',
#  'fBodyBodyGyroJerkMag-meanFreq()': 'fBodyBodyGyroJerkMagmeanFreq',
#  'fBodyBodyGyroJerkMag-min()': 'fBodyBodyGyroJerkMagmin',
#  'fBodyBodyGyroJerkMag-skewness()': 'fBodyBodyGyroJerkMagskewness',
#  'fBodyBodyGyroJerkMag-sma()': 'fBodyBodyGyroJerkMagsma',
#  'fBodyBodyGyroJerkMag-std()': 'fBodyBodyGyroJerkMagstd',
#  'fBodyBodyGyroMag-energy()': 'fBodyBodyGyroMagenergy',
#  'fBodyBodyGyroMag-entropy()': 'fBodyBodyGyroMagentropy',
#  'fBodyBodyGyroMag-iqr()': 'fBodyBodyGyroMagiqr',
#  'fBodyBodyGyroMag-kurtosis()': 'fBodyBodyGyroMagkurtosis',
#  'fBodyBodyGyroMag-mad()': 'fBodyBodyGyroMagmad',
#  'fBodyBodyGyroMag-max()': 'fBodyBodyGyroMagmax',
#  'fBodyBodyGyroMag-maxInds': 'fBodyBodyGyroMagmaxInds',
#  'fBodyBodyGyroMag-mean()': 'fBodyBodyGyroMagmean',
#  'fBodyBodyGyroMag-meanFreq()': 'fBodyBodyGyroMagmeanFreq',
#  'fBodyBodyGyroMag-min()': 'fBodyBodyGyroMagmin',
#  'fBodyBodyGyroMag-skewness()': 'fBodyBodyGyroMagskewness',
#  'fBodyBodyGyroMag-sma()': 'fBodyBodyGyroMagsma',
#  'fBodyBodyGyroMag-std()': 'fBodyBodyGyroMagstd',
#  'fBodyGyro-bandsEnergy()-1,16': 'fBodyGyrobandsEnergy116',
#  'fBodyGyro-bandsEnergy()-1,16.1': 'fBodyGyrobandsEnergy116.1',
#  'fBodyGyro-bandsEnergy()-1,16.2': 'fBodyGyrobandsEnergy116.2',
#  'fBodyGyro-bandsEnergy()-1,24': 'fBodyGyrobandsEnergy124',
#  'fBodyGyro-bandsEnergy()-1,24.1': 'fBodyGyrobandsEnergy124.1',
#  'fBodyGyro-bandsEnergy()-1,24.2': 'fBodyGyrobandsEnergy124.2',
#  'fBodyGyro-bandsEnergy()-1,8': 'fBodyGyrobandsEnergy18',
#  'fBodyGyro-bandsEnergy()-1,8.1': 'fBodyGyrobandsEnergy18.1',
#  'fBodyGyro-bandsEnergy()-1,8.2': 'fBodyGyrobandsEnergy18.2',
#  'fBodyGyro-bandsEnergy()-17,24': 'fBodyGyrobandsEnergy1724',
#  'fBodyGyro-bandsEnergy()-17,24.1': 'fBodyGyrobandsEnergy1724.1',
#  'fBodyGyro-bandsEnergy()-17,24.2': 'fBodyGyrobandsEnergy1724.2',
#  'fBodyGyro-bandsEnergy()-17,32': 'fBodyGyrobandsEnergy1732',
#  'fBodyGyro-bandsEnergy()-17,32.1': 'fBodyGyrobandsEnergy1732.1',
#  'fBodyGyro-bandsEnergy()-17,32.2': 'fBodyGyrobandsEnergy1732.2',
#  'fBodyGyro-bandsEnergy()-25,32': 'fBodyGyrobandsEnergy2532',
#  'fBodyGyro-bandsEnergy()-25,32.1': 'fBodyGyrobandsEnergy2532.1',
#  'fBodyGyro-bandsEnergy()-25,32.2': 'fBodyGyrobandsEnergy2532.2',
#  'fBodyGyro-bandsEnergy()-25,48': 'fBodyGyrobandsEnergy2548',
#  'fBodyGyro-bandsEnergy()-25,48.1': 'fBodyGyrobandsEnergy2548.1',
#  'fBodyGyro-bandsEnergy()-25,48.2': 'fBodyGyrobandsEnergy2548.2',
#  'fBodyGyro-bandsEnergy()-33,40': 'fBodyGyrobandsEnergy3340',
#  'fBodyGyro-bandsEnergy()-33,40.1': 'fBodyGyrobandsEnergy3340.1',
#  'fBodyGyro-bandsEnergy()-33,40.2': 'fBodyGyrobandsEnergy3340.2',
#  'fBodyGyro-bandsEnergy()-33,48': 'fBodyGyrobandsEnergy3348',
#  'fBodyGyro-bandsEnergy()-33,48.1': 'fBodyGyrobandsEnergy3348.1',
#  'fBodyGyro-bandsEnergy()-33,48.2': 'fBodyGyrobandsEnergy3348.2',
#  'fBodyGyro-bandsEnergy()-41,48': 'fBodyGyrobandsEnergy4148',
#  'fBodyGyro-bandsEnergy()-41,48.1': 'fBodyGyrobandsEnergy4148.1',
#  'fBodyGyro-bandsEnergy()-41,48.2': 'fBodyGyrobandsEnergy4148.2',
#  'fBodyGyro-bandsEnergy()-49,56': 'fBodyGyrobandsEnergy4956',
#  'fBodyGyro-bandsEnergy()-49,56.1': 'fBodyGyrobandsEnergy4956.1',
#  'fBodyGyro-bandsEnergy()-49,56.2': 'fBodyGyrobandsEnergy4956.2',
#  'fBodyGyro-bandsEnergy()-49,64': 'fBodyGyrobandsEnergy4964',
#  'fBodyGyro-bandsEnergy()-49,64.1': 'fBodyGyrobandsEnergy4964.1',
#  'fBodyGyro-bandsEnergy()-49,64.2': 'fBodyGyrobandsEnergy4964.2',
#  'fBodyGyro-bandsEnergy()-57,64': 'fBodyGyrobandsEnergy5764',
#  'fBodyGyro-bandsEnergy()-57,64.1': 'fBodyGyrobandsEnergy5764.1',
#  'fBodyGyro-bandsEnergy()-57,64.2': 'fBodyGyrobandsEnergy5764.2',
#  'fBodyGyro-bandsEnergy()-9,16': 'fBodyGyrobandsEnergy916',
#  'fBodyGyro-bandsEnergy()-9,16.1': 'fBodyGyrobandsEnergy916.1',
#  'fBodyGyro-bandsEnergy()-9,16.2': 'fBodyGyrobandsEnergy916.2',
#  'fBodyGyro-energy()-X': 'fBodyGyroenergyX',
#  'fBodyGyro-energy()-Y': 'fBodyGyroenergyY',
#  'fBodyGyro-energy()-Z': 'fBodyGyroenergyZ',
#  'fBodyGyro-entropy()-X': 'fBodyGyroentropyX',
#  'fBodyGyro-entropy()-Y': 'fBodyGyroentropyY',
#  'fBodyGyro-entropy()-Z': 'fBodyGyroentropyZ',
#  'fBodyGyro-iqr()-X': 'fBodyGyroiqrX',
#  'fBodyGyro-iqr()-Y': 'fBodyGyroiqrY',
#  'fBodyGyro-iqr()-Z': 'fBodyGyroiqrZ',
#  'fBodyGyro-kurtosis()-X': 'fBodyGyrokurtosisX',
#  'fBodyGyro-kurtosis()-Y': 'fBodyGyrokurtosisY',
#  'fBodyGyro-kurtosis()-Z': 'fBodyGyrokurtosisZ',
#  'fBodyGyro-mad()-X': 'fBodyGyromadX',
#  'fBodyGyro-mad()-Y': 'fBodyGyromadY',
#  'fBodyGyro-mad()-Z': 'fBodyGyromadZ',
#  'fBodyGyro-max()-X': 'fBodyGyromaxX',
#  'fBodyGyro-max()-Y': 'fBodyGyromaxY',
#  'fBodyGyro-max()-Z': 'fBodyGyromaxZ',
#  'fBodyGyro-maxInds-X': 'fBodyGyromaxIndsX',
#  'fBodyGyro-maxInds-Y': 'fBodyGyromaxIndsY',
#  'fBodyGyro-maxInds-Z': 'fBodyGyromaxIndsZ',
#  'fBodyGyro-mean()-X': 'fBodyGyromeanX',
#  'fBodyGyro-mean()-Y': 'fBodyGyromeanY',
#  'fBodyGyro-mean()-Z': 'fBodyGyromeanZ',
#  'fBodyGyro-meanFreq()-X': 'fBodyGyromeanFreqX',
#  'fBodyGyro-meanFreq()-Y': 'fBodyGyromeanFreqY',
#  'fBodyGyro-meanFreq()-Z': 'fBodyGyromeanFreqZ',
#  'fBodyGyro-min()-X': 'fBodyGyrominX',
#  'fBodyGyro-min()-Y': 'fBodyGyrominY',
#  'fBodyGyro-min()-Z': 'fBodyGyrominZ',
#  'fBodyGyro-skewness()-X': 'fBodyGyroskewnessX',
#  'fBodyGyro-skewness()-Y': 'fBodyGyroskewnessY',
#  'fBodyGyro-skewness()-Z': 'fBodyGyroskewnessZ',
#  'fBodyGyro-sma()': 'fBodyGyrosma',
#  'fBodyGyro-std()-X': 'fBodyGyrostdX',
#  'fBodyGyro-std()-Y': 'fBodyGyrostdY',
#  'fBodyGyro-std()-Z': 'fBodyGyrostdZ',
#  'subject': 'subject',
#  'tBodyAcc-arCoeff()-X,1': 'tBodyAccarCoeffX1',
#  'tBodyAcc-arCoeff()-X,2': 'tBodyAccarCoeffX2',
#  'tBodyAcc-arCoeff()-X,3': 'tBodyAccarCoeffX3',
#  'tBodyAcc-arCoeff()-X,4': 'tBodyAccarCoeffX4',
#  'tBodyAcc-arCoeff()-Y,1': 'tBodyAccarCoeffY1',
#  'tBodyAcc-arCoeff()-Y,2': 'tBodyAccarCoeffY2',
#  'tBodyAcc-arCoeff()-Y,3': 'tBodyAccarCoeffY3',
#  'tBodyAcc-arCoeff()-Y,4': 'tBodyAccarCoeffY4',
#  'tBodyAcc-arCoeff()-Z,1': 'tBodyAccarCoeffZ1',
#  'tBodyAcc-arCoeff()-Z,2': 'tBodyAccarCoeffZ2',
#  'tBodyAcc-arCoeff()-Z,3': 'tBodyAccarCoeffZ3',
#  'tBodyAcc-arCoeff()-Z,4': 'tBodyAccarCoeffZ4',
#  'tBodyAcc-correlation()-X,Y': 'tBodyAcccorrelationXY',
#  'tBodyAcc-correlation()-X,Z': 'tBodyAcccorrelationXZ',
#  'tBodyAcc-correlation()-Y,Z': 'tBodyAcccorrelationYZ',
#  'tBodyAcc-energy()-X': 'tBodyAccenergyX',
#  'tBodyAcc-energy()-Y': 'tBodyAccenergyY',
#  'tBodyAcc-energy()-Z': 'tBodyAccenergyZ',
#  'tBodyAcc-entropy()-X': 'tBodyAccentropyX',
#  'tBodyAcc-entropy()-Y': 'tBodyAccentropyY',
#  'tBodyAcc-entropy()-Z': 'tBodyAccentropyZ',
#  'tBodyAcc-iqr()-X': 'tBodyAcciqrX',
#  'tBodyAcc-iqr()-Y': 'tBodyAcciqrY',
#  'tBodyAcc-iqr()-Z': 'tBodyAcciqrZ',
#  'tBodyAcc-mad()-X': 'tBodyAccmadX',
#  'tBodyAcc-mad()-Y': 'tBodyAccmadY',
#  'tBodyAcc-mad()-Z': 'tBodyAccmadZ',
#  'tBodyAcc-max()-X': 'tBodyAccmaxX',
#  'tBodyAcc-max()-Y': 'tBodyAccmaxY',
#  'tBodyAcc-max()-Z': 'tBodyAccmaxZ',
#  'tBodyAcc-mean()-X': 'tBodyAccmeanX',
#  'tBodyAcc-mean()-Y': 'tBodyAccmeanY',
#  'tBodyAcc-mean()-Z': 'tBodyAccmeanZ',
#  'tBodyAcc-min()-X': 'tBodyAccminX',
#  'tBodyAcc-min()-Y': 'tBodyAccminY',
#  'tBodyAcc-min()-Z': 'tBodyAccminZ',
#  'tBodyAcc-sma()': 'tBodyAccsma',
#  'tBodyAcc-std()-X': 'tBodyAccstdX',
#  'tBodyAcc-std()-Y': 'tBodyAccstdY',
#  'tBodyAcc-std()-Z': 'tBodyAccstdZ',
#  'tBodyAccJerk-arCoeff()-X,1': 'tBodyAccJerkarCoeffX1',
#  'tBodyAccJerk-arCoeff()-X,2': 'tBodyAccJerkarCoeffX2',
#  'tBodyAccJerk-arCoeff()-X,3': 'tBodyAccJerkarCoeffX3',
#  'tBodyAccJerk-arCoeff()-X,4': 'tBodyAccJerkarCoeffX4',
#  'tBodyAccJerk-arCoeff()-Y,1': 'tBodyAccJerkarCoeffY1',
#  'tBodyAccJerk-arCoeff()-Y,2': 'tBodyAccJerkarCoeffY2',
#  'tBodyAccJerk-arCoeff()-Y,3': 'tBodyAccJerkarCoeffY3',
#  'tBodyAccJerk-arCoeff()-Y,4': 'tBodyAccJerkarCoeffY4',
#  'tBodyAccJerk-arCoeff()-Z,1': 'tBodyAccJerkarCoeffZ1',
#  'tBodyAccJerk-arCoeff()-Z,2': 'tBodyAccJerkarCoeffZ2',
#  'tBodyAccJerk-arCoeff()-Z,3': 'tBodyAccJerkarCoeffZ3',
#  'tBodyAccJerk-arCoeff()-Z,4': 'tBodyAccJerkarCoeffZ4',
#  'tBodyAccJerk-correlation()-X,Y': 'tBodyAccJerkcorrelationXY',
#  'tBodyAccJerk-correlation()-X,Z': 'tBodyAccJerkcorrelationXZ',
#  'tBodyAccJerk-correlation()-Y,Z': 'tBodyAccJerkcorrelationYZ',
#  'tBodyAccJerk-energy()-X': 'tBodyAccJerkenergyX',
#  'tBodyAccJerk-energy()-Y': 'tBodyAccJerkenergyY',
#  'tBodyAccJerk-energy()-Z': 'tBodyAccJerkenergyZ',
#  'tBodyAccJerk-entropy()-X': 'tBodyAccJerkentropyX',
#  'tBodyAccJerk-entropy()-Y': 'tBodyAccJerkentropyY',
#  'tBodyAccJerk-entropy()-Z': 'tBodyAccJerkentropyZ',
#  'tBodyAccJerk-iqr()-X': 'tBodyAccJerkiqrX',
#  'tBodyAccJerk-iqr()-Y': 'tBodyAccJerkiqrY',
#  'tBodyAccJerk-iqr()-Z': 'tBodyAccJerkiqrZ',
#  'tBodyAccJerk-mad()-X': 'tBodyAccJerkmadX',
#  'tBodyAccJerk-mad()-Y': 'tBodyAccJerkmadY',
#  'tBodyAccJerk-mad()-Z': 'tBodyAccJerkmadZ',
#  'tBodyAccJerk-max()-X': 'tBodyAccJerkmaxX',
#  'tBodyAccJerk-max()-Y': 'tBodyAccJerkmaxY',
#  'tBodyAccJerk-max()-Z': 'tBodyAccJerkmaxZ',
#  'tBodyAccJerk-mean()-X': 'tBodyAccJerkmeanX',
#  'tBodyAccJerk-mean()-Y': 'tBodyAccJerkmeanY',
#  'tBodyAccJerk-mean()-Z': 'tBodyAccJerkmeanZ',
#  'tBodyAccJerk-min()-X': 'tBodyAccJerkminX',
#  'tBodyAccJerk-min()-Y': 'tBodyAccJerkminY',
#  'tBodyAccJerk-min()-Z': 'tBodyAccJerkminZ',
#  'tBodyAccJerk-sma()': 'tBodyAccJerksma',
#  'tBodyAccJerk-std()-X': 'tBodyAccJerkstdX',
#  'tBodyAccJerk-std()-Y': 'tBodyAccJerkstdY',
#  'tBodyAccJerk-std()-Z': 'tBodyAccJerkstdZ',
#  'tBodyAccJerkMag-arCoeff()1': 'tBodyAccJerkMagarCoeff1',
#  'tBodyAccJerkMag-arCoeff()2': 'tBodyAccJerkMagarCoeff2',
#  'tBodyAccJerkMag-arCoeff()3': 'tBodyAccJerkMagarCoeff3',
#  'tBodyAccJerkMag-arCoeff()4': 'tBodyAccJerkMagarCoeff4',
#  'tBodyAccJerkMag-energy()': 'tBodyAccJerkMagenergy',
#  'tBodyAccJerkMag-entropy()': 'tBodyAccJerkMagentropy',
#  'tBodyAccJerkMag-iqr()': 'tBodyAccJerkMagiqr',
#  'tBodyAccJerkMag-mad()': 'tBodyAccJerkMagmad',
#  'tBodyAccJerkMag-max()': 'tBodyAccJerkMagmax',
#  'tBodyAccJerkMag-mean()': 'tBodyAccJerkMagmean',
#  'tBodyAccJerkMag-min()': 'tBodyAccJerkMagmin',
#  'tBodyAccJerkMag-sma()': 'tBodyAccJerkMagsma',
#  'tBodyAccJerkMag-std()': 'tBodyAccJerkMagstd',
#  'tBodyAccMag-arCoeff()1': 'tBodyAccMagarCoeff1',
#  'tBodyAccMag-arCoeff()2': 'tBodyAccMagarCoeff2',
#  'tBodyAccMag-arCoeff()3': 'tBodyAccMagarCoeff3',
#  'tBodyAccMag-arCoeff()4': 'tBodyAccMagarCoeff4',
#  'tBodyAccMag-energy()': 'tBodyAccMagenergy',
#  'tBodyAccMag-entropy()': 'tBodyAccMagentropy',
#  'tBodyAccMag-iqr()': 'tBodyAccMagiqr',
#  'tBodyAccMag-mad()': 'tBodyAccMagmad',
#  'tBodyAccMag-max()': 'tBodyAccMagmax',
#  'tBodyAccMag-mean()': 'tBodyAccMagmean',
#  'tBodyAccMag-min()': 'tBodyAccMagmin',
#  'tBodyAccMag-sma()': 'tBodyAccMagsma',
#  'tBodyAccMag-std()': 'tBodyAccMagstd',
#  'tBodyGyro-arCoeff()-X,1': 'tBodyGyroarCoeffX1',
#  'tBodyGyro-arCoeff()-X,2': 'tBodyGyroarCoeffX2',
#  'tBodyGyro-arCoeff()-X,3': 'tBodyGyroarCoeffX3',
#  'tBodyGyro-arCoeff()-X,4': 'tBodyGyroarCoeffX4',
#  'tBodyGyro-arCoeff()-Y,1': 'tBodyGyroarCoeffY1',
#  'tBodyGyro-arCoeff()-Y,2': 'tBodyGyroarCoeffY2',
#  'tBodyGyro-arCoeff()-Y,3': 'tBodyGyroarCoeffY3',
#  'tBodyGyro-arCoeff()-Y,4': 'tBodyGyroarCoeffY4',
#  'tBodyGyro-arCoeff()-Z,1': 'tBodyGyroarCoeffZ1',
#  'tBodyGyro-arCoeff()-Z,2': 'tBodyGyroarCoeffZ2',
#  'tBodyGyro-arCoeff()-Z,3': 'tBodyGyroarCoeffZ3',
#  'tBodyGyro-arCoeff()-Z,4': 'tBodyGyroarCoeffZ4',
#  'tBodyGyro-correlation()-X,Y': 'tBodyGyrocorrelationXY',
#  'tBodyGyro-correlation()-X,Z': 'tBodyGyrocorrelationXZ',
#  'tBodyGyro-correlation()-Y,Z': 'tBodyGyrocorrelationYZ',
#  'tBodyGyro-energy()-X': 'tBodyGyroenergyX',
#  'tBodyGyro-energy()-Y': 'tBodyGyroenergyY',
#  'tBodyGyro-energy()-Z': 'tBodyGyroenergyZ',
#  'tBodyGyro-entropy()-X': 'tBodyGyroentropyX',
#  'tBodyGyro-entropy()-Y': 'tBodyGyroentropyY',
#  'tBodyGyro-entropy()-Z': 'tBodyGyroentropyZ',
#  'tBodyGyro-iqr()-X': 'tBodyGyroiqrX',
#  'tBodyGyro-iqr()-Y': 'tBodyGyroiqrY',
#  'tBodyGyro-iqr()-Z': 'tBodyGyroiqrZ',
#  'tBodyGyro-mad()-X': 'tBodyGyromadX',
#  'tBodyGyro-mad()-Y': 'tBodyGyromadY',
#  'tBodyGyro-mad()-Z': 'tBodyGyromadZ',
#  'tBodyGyro-max()-X': 'tBodyGyromaxX',
#  'tBodyGyro-max()-Y': 'tBodyGyromaxY',
#  'tBodyGyro-max()-Z': 'tBodyGyromaxZ',
#  'tBodyGyro-mean()-X': 'tBodyGyromeanX',
#  'tBodyGyro-mean()-Y': 'tBodyGyromeanY',
#  'tBodyGyro-mean()-Z': 'tBodyGyromeanZ',
#  'tBodyGyro-min()-X': 'tBodyGyrominX',
#  'tBodyGyro-min()-Y': 'tBodyGyrominY',
#  'tBodyGyro-min()-Z': 'tBodyGyrominZ',
#  'tBodyGyro-sma()': 'tBodyGyrosma',
#  'tBodyGyro-std()-X': 'tBodyGyrostdX',
#  'tBodyGyro-std()-Y': 'tBodyGyrostdY',
#  'tBodyGyro-std()-Z': 'tBodyGyrostdZ',
#  'tBodyGyroJerk-arCoeff()-X,1': 'tBodyGyroJerkarCoeffX1',
#  'tBodyGyroJerk-arCoeff()-X,2': 'tBodyGyroJerkarCoeffX2',
#  'tBodyGyroJerk-arCoeff()-X,3': 'tBodyGyroJerkarCoeffX3',
#  'tBodyGyroJerk-arCoeff()-X,4': 'tBodyGyroJerkarCoeffX4',
#  'tBodyGyroJerk-arCoeff()-Y,1': 'tBodyGyroJerkarCoeffY1',
#  'tBodyGyroJerk-arCoeff()-Y,2': 'tBodyGyroJerkarCoeffY2',
#  'tBodyGyroJerk-arCoeff()-Y,3': 'tBodyGyroJerkarCoeffY3',
#  'tBodyGyroJerk-arCoeff()-Y,4': 'tBodyGyroJerkarCoeffY4',
#  'tBodyGyroJerk-arCoeff()-Z,1': 'tBodyGyroJerkarCoeffZ1',
#  'tBodyGyroJerk-arCoeff()-Z,2': 'tBodyGyroJerkarCoeffZ2',
#  'tBodyGyroJerk-arCoeff()-Z,3': 'tBodyGyroJerkarCoeffZ3',
#  'tBodyGyroJerk-arCoeff()-Z,4': 'tBodyGyroJerkarCoeffZ4',
#  'tBodyGyroJerk-correlation()-X,Y': 'tBodyGyroJerkcorrelationXY',
#  'tBodyGyroJerk-correlation()-X,Z': 'tBodyGyroJerkcorrelationXZ',
#  'tBodyGyroJerk-correlation()-Y,Z': 'tBodyGyroJerkcorrelationYZ',
#  'tBodyGyroJerk-energy()-X': 'tBodyGyroJerkenergyX',
#  'tBodyGyroJerk-energy()-Y': 'tBodyGyroJerkenergyY',
#  'tBodyGyroJerk-energy()-Z': 'tBodyGyroJerkenergyZ',
#  'tBodyGyroJerk-entropy()-X': 'tBodyGyroJerkentropyX',
#  'tBodyGyroJerk-entropy()-Y': 'tBodyGyroJerkentropyY',
#  'tBodyGyroJerk-entropy()-Z': 'tBodyGyroJerkentropyZ',
#  'tBodyGyroJerk-iqr()-X': 'tBodyGyroJerkiqrX',
#  'tBodyGyroJerk-iqr()-Y': 'tBodyGyroJerkiqrY',
#  'tBodyGyroJerk-iqr()-Z': 'tBodyGyroJerkiqrZ',
#  'tBodyGyroJerk-mad()-X': 'tBodyGyroJerkmadX',
#  'tBodyGyroJerk-mad()-Y': 'tBodyGyroJerkmadY',
#  'tBodyGyroJerk-mad()-Z': 'tBodyGyroJerkmadZ',
#  'tBodyGyroJerk-max()-X': 'tBodyGyroJerkmaxX',
#  'tBodyGyroJerk-max()-Y': 'tBodyGyroJerkmaxY',
#  'tBodyGyroJerk-max()-Z': 'tBodyGyroJerkmaxZ',
#  'tBodyGyroJerk-mean()-X': 'tBodyGyroJerkmeanX',
#  'tBodyGyroJerk-mean()-Y': 'tBodyGyroJerkmeanY',
#  'tBodyGyroJerk-mean()-Z': 'tBodyGyroJerkmeanZ',
#  'tBodyGyroJerk-min()-X': 'tBodyGyroJerkminX',
#  'tBodyGyroJerk-min()-Y': 'tBodyGyroJerkminY',
#  'tBodyGyroJerk-min()-Z': 'tBodyGyroJerkminZ',
#  'tBodyGyroJerk-sma()': 'tBodyGyroJerksma',
#  'tBodyGyroJerk-std()-X': 'tBodyGyroJerkstdX',
#  'tBodyGyroJerk-std()-Y': 'tBodyGyroJerkstdY',
#  'tBodyGyroJerk-std()-Z': 'tBodyGyroJerkstdZ',
#  'tBodyGyroJerkMag-arCoeff()1': 'tBodyGyroJerkMagarCoeff1',
#  'tBodyGyroJerkMag-arCoeff()2': 'tBodyGyroJerkMagarCoeff2',
#  'tBodyGyroJerkMag-arCoeff()3': 'tBodyGyroJerkMagarCoeff3',
#  'tBodyGyroJerkMag-arCoeff()4': 'tBodyGyroJerkMagarCoeff4',
#  'tBodyGyroJerkMag-energy()': 'tBodyGyroJerkMagenergy',
#  'tBodyGyroJerkMag-entropy()': 'tBodyGyroJerkMagentropy',
#  'tBodyGyroJerkMag-iqr()': 'tBodyGyroJerkMagiqr',
#  'tBodyGyroJerkMag-mad()': 'tBodyGyroJerkMagmad',
#  'tBodyGyroJerkMag-max()': 'tBodyGyroJerkMagmax',
#  'tBodyGyroJerkMag-mean()': 'tBodyGyroJerkMagmean',
#  'tBodyGyroJerkMag-min()': 'tBodyGyroJerkMagmin',
#  'tBodyGyroJerkMag-sma()': 'tBodyGyroJerkMagsma',
#  'tBodyGyroJerkMag-std()': 'tBodyGyroJerkMagstd',
#  'tBodyGyroMag-arCoeff()1': 'tBodyGyroMagarCoeff1',
#  'tBodyGyroMag-arCoeff()2': 'tBodyGyroMagarCoeff2',
#  'tBodyGyroMag-arCoeff()3': 'tBodyGyroMagarCoeff3',
#  'tBodyGyroMag-arCoeff()4': 'tBodyGyroMagarCoeff4',
#  'tBodyGyroMag-energy()': 'tBodyGyroMagenergy',
#  'tBodyGyroMag-entropy()': 'tBodyGyroMagentropy',
#  'tBodyGyroMag-iqr()': 'tBodyGyroMagiqr',
#  'tBodyGyroMag-mad()': 'tBodyGyroMagmad',
#  'tBodyGyroMag-max()': 'tBodyGyroMagmax',
#  'tBodyGyroMag-mean()': 'tBodyGyroMagmean',
#  'tBodyGyroMag-min()': 'tBodyGyroMagmin',
#  'tBodyGyroMag-sma()': 'tBodyGyroMagsma',
#  'tBodyGyroMag-std()': 'tBodyGyroMagstd',
#  'tGravityAcc-arCoeff()-X,1': 'tGravityAccarCoeffX1',
#  'tGravityAcc-arCoeff()-X,2': 'tGravityAccarCoeffX2',
#  'tGravityAcc-arCoeff()-X,3': 'tGravityAccarCoeffX3',
#  'tGravityAcc-arCoeff()-X,4': 'tGravityAccarCoeffX4',
#  'tGravityAcc-arCoeff()-Y,1': 'tGravityAccarCoeffY1',
#  'tGravityAcc-arCoeff()-Y,2': 'tGravityAccarCoeffY2',
#  'tGravityAcc-arCoeff()-Y,3': 'tGravityAccarCoeffY3',
#  'tGravityAcc-arCoeff()-Y,4': 'tGravityAccarCoeffY4',
#  'tGravityAcc-arCoeff()-Z,1': 'tGravityAccarCoeffZ1',
#  'tGravityAcc-arCoeff()-Z,2': 'tGravityAccarCoeffZ2',
#  'tGravityAcc-arCoeff()-Z,3': 'tGravityAccarCoeffZ3',
#  'tGravityAcc-arCoeff()-Z,4': 'tGravityAccarCoeffZ4',
#  'tGravityAcc-correlation()-X,Y': 'tGravityAcccorrelationXY',
#  'tGravityAcc-correlation()-X,Z': 'tGravityAcccorrelationXZ',
#  'tGravityAcc-correlation()-Y,Z': 'tGravityAcccorrelationYZ',
#  'tGravityAcc-energy()-X': 'tGravityAccenergyX',
#  'tGravityAcc-energy()-Y': 'tGravityAccenergyY',
#  'tGravityAcc-energy()-Z': 'tGravityAccenergyZ',
#  'tGravityAcc-entropy()-X': 'tGravityAccentropyX',
#  'tGravityAcc-entropy()-Y': 'tGravityAccentropyY',
#  'tGravityAcc-entropy()-Z': 'tGravityAccentropyZ',
#  'tGravityAcc-iqr()-X': 'tGravityAcciqrX',
#  'tGravityAcc-iqr()-Y': 'tGravityAcciqrY',
#  'tGravityAcc-iqr()-Z': 'tGravityAcciqrZ',
#  'tGravityAcc-mad()-X': 'tGravityAccmadX',
#  'tGravityAcc-mad()-Y': 'tGravityAccmadY',
#  'tGravityAcc-mad()-Z': 'tGravityAccmadZ',
#  'tGravityAcc-max()-X': 'tGravityAccmaxX',
#  'tGravityAcc-max()-Y': 'tGravityAccmaxY',
#  'tGravityAcc-max()-Z': 'tGravityAccmaxZ',
#  'tGravityAcc-mean()-X': 'tGravityAccmeanX',
#  'tGravityAcc-mean()-Y': 'tGravityAccmeanY',
#  'tGravityAcc-mean()-Z': 'tGravityAccmeanZ',
#  'tGravityAcc-min()-X': 'tGravityAccminX',
#  'tGravityAcc-min()-Y': 'tGravityAccminY',
#  'tGravityAcc-min()-Z': 'tGravityAccminZ',
#  'tGravityAcc-sma()': 'tGravityAccsma',
#  'tGravityAcc-std()-X': 'tGravityAccstdX',
#  'tGravityAcc-std()-Y': 'tGravityAccstdY',
#  'tGravityAcc-std()-Z': 'tGravityAccstdZ',
#  'tGravityAccMag-arCoeff()1': 'tGravityAccMagarCoeff1',
#  'tGravityAccMag-arCoeff()2': 'tGravityAccMagarCoeff2',
#  'tGravityAccMag-arCoeff()3': 'tGravityAccMagarCoeff3',
#  'tGravityAccMag-arCoeff()4': 'tGravityAccMagarCoeff4',
#  'tGravityAccMag-energy()': 'tGravityAccMagenergy',
#  'tGravityAccMag-entropy()': 'tGravityAccMagentropy',
#  'tGravityAccMag-iqr()': 'tGravityAccMagiqr',
#  'tGravityAccMag-mad()': 'tGravityAccMagmad',
#  'tGravityAccMag-max()': 'tGravityAccMagmax',
#  'tGravityAccMag-mean()': 'tGravityAccMagmean',
#  'tGravityAccMag-min()': 'tGravityAccMagmin',
#  'tGravityAccMag-sma()': 'tGravityAccMagsma',
#  'tGravityAccMag-std()': 'tGravityAccMagstd'}

# %%
# Check to make sure the values in cols_new_names are all unique
import numpy as np

cols_new_names_values = list(cols_new_names.values())
print len(cols_new_names_values)
print len(np.unique(cols_new_names_values))
# Out:
# 564
# 564

# %% [markdown]
# Bummer, after we renamed the columns we ended up creating duplicates

# %%
# Find out what the duplicates are
from collections import Counter
dupes = [item for item, count in Counter(cols_new_names_values).iteritems() if count > 1]

# %%
dupes
# Out:
# []

# %%
# Rename cols
sf.rename(cols_new_names)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-84-c33035b1b26c> in <module>()
#       1 # Rename cols
# ----> 2 sf.rename(cols_new_names)
#
# F:\Users\Ty\Anaconda\lib\site-packages\graphlab\data_structures\sframe.pyc in rename(self, names)
#    3526             for k in names:
#    3527                 colid = self.column_names().index(k)
# -> 3528                 self.__proxy__.set_column_name(colid, names[k])
#    3529         self._cache = None
#    3530         return self
#
# F:\Users\Ty\Anaconda\lib\site-packages\graphlab\cython\context.pyc in __exit__(self, exc_type, exc_value, traceback)
#      47             if not self.show_cython_trace:
#      48                 # To hide cython trace, we re-raise from here
# ---> 49                 raise exc_type(exc_value)
#      50             else:
#      51                 # To show the full trace, we do nothing and let exception propagate
#
# RuntimeError: Runtime Exception. Column name fAccsma already exists
